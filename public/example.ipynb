# %% [markdown]
# # CrekAI Assignment: NumPy Basics - Step 1
#
# Welcome to your first NumPy assignment! Complete the exercises below to practice what you've learned.
#
# **Important:** Make sure to run the verification cell at the end to mark this assignment as complete!

# %% [markdown]
# ## Setup
# First, let's import NumPy

# %%
import numpy as np
print(f"NumPy version: {np.__version__}")

# %% [markdown]
# ## Exercise 1: Create Arrays
# Create a NumPy array with numbers from 1 to 10

# %%
# Your code here
arr = np.arange(1, 11)
print(arr)

# %% [markdown]
# ## Exercise 2: Array Operations
# Multiply all elements in the array by 2

# %%
# Your code here
arr_doubled = arr * 2
print(arr_doubled)

# %% [markdown]
# ## Exercise 3: Array Statistics
# Calculate the mean, median, and standard deviation of your array

# %%
# Your code here
mean = np.mean(arr)
median = np.median(arr)
std = np.std(arr)

print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Standard Deviation: {std}")

# %% [markdown]
# ---
# ## 🎯 Assignment Verification
#
# **IMPORTANT:** Run this cell to verify your assignment completion and unlock the next step!
#
# ### Instructions:
# 1. Copy your unique token from the CrekAI project page
# 2. Paste it in the `USER_TOKEN` field below
# 3. Make sure `STEP` matches your current step number
# 4. Run this cell to verify completion

# %%
import requests

# ===== PASTE YOUR TOKEN HERE =====
USER_TOKEN = "paste_your_token_here"
# =================================

PROJECT_ID = "learn-numpy"
STEP = 1  # Current step number

# Verification endpoint
API_URL = "https://your-domain.com/api/track-execution"

print("🔄 Verifying assignment completion...")
print()

try:
    response = requests.post(
        API_URL,
        json={
            "token": USER_TOKEN,
            "project_id": PROJECT_ID,
            "step": STEP
        },
        timeout=10
    )
    
    if response.status_code == 200:
        data = response.json()
        print("✅ SUCCESS! Assignment completed and verified!")
        print(f"📊 {data.get('message', '')}")
        if data.get('next_step'):
            print(f"🚀 Next step unlocked: Step {data['next_step']}")
        print("\n👉 Return to CrekAI to continue learning!")
    else:
        print(f"❌ Verification failed: {response.status_code}")
        try:
            error_data = response.json()
            print(f"Error: {error_data.get('error', 'Unknown error')}")
        except:
            print("Please check your token and try again.")
        
except requests.exceptions.RequestException as e:
    print(f"❌ Network error: {e}")
    print("Please check your internet connection and try again.")
except Exception as e:
    print(f"❌ Error: {e}")
    print("Please check your configuration and try again.")

# %% [markdown]
# ---
#
# ### Troubleshooting
#
# If verification fails:
# 1. Make sure you copied the correct token from CrekAI
# 2. Verify the `PROJECT_ID` matches your project
# 3. Ensure `STEP` is the correct step number
# 4. Check that you completed all exercises above
# 5. Try regenerating your token on CrekAI if needed
